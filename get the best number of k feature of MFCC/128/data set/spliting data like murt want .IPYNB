# %%
import pandas as pd

# %%
data_all=pd.read_csv("all data\\df_128f.csv")

# %%
data_all
# Out:
#     label          0           1          2          3          4          5  \
# 0    real -338.08353   67.911930  41.633290  61.226604  -7.420347 -29.123165
# 1    real -310.41990  103.214806  -5.251594  -7.131568 -14.951820  -7.724176
# 2    real -266.00845  111.628910 -36.322277  -7.016376 -12.474454 -23.655554
# 3    real -260.43338  101.535420 -41.664314  -6.018332 -26.039772 -23.073729
# 4    real -296.36484   68.708840  16.257040  -0.410207 -11.122212  -6.175922
# ..    ...        ...         ...        ...        ...        ...        ...
# 192  fake -296.73276   98.087870  -6.969804   9.237810 -14.932974 -26.105984
# 193  fake -297.21432   72.656850  14.818332  14.452042 -16.384123 -19.401957
# 194  fake -275.80368   80.892390   8.894267   7.113605 -22.349508 -25.666887
# 195  fake -295.57413   86.443110 -12.279798   8.740219 -14.250678 -21.122461
# 196  fake -292.48965   72.542625   4.686722  11.017757 -17.455631 -13.377519
#
# ...

# %%
real=data_all[data_all['label']=='real']
fake=data_all[data_all['label']!='real']
# real=data_all[data_all['label']==1]
# fake=data_all[data_all['label']==0]

# %%
real
# Out:
#    label          0           1          2          3          4          5  \
# 0   real -338.08353   67.911930  41.633290  61.226604  -7.420347 -29.123165
# 1   real -310.41990  103.214806  -5.251594  -7.131568 -14.951820  -7.724176
# 2   real -266.00845  111.628910 -36.322277  -7.016376 -12.474454 -23.655554
# 3   real -260.43338  101.535420 -41.664314  -6.018332 -26.039772 -23.073729
# 4   real -296.36484   68.708840  16.257040  -0.410207 -11.122212  -6.175922
# ..   ...        ...         ...        ...        ...        ...        ...
# 95  real -290.67993   42.997128  23.133880  31.650919 -19.173588 -19.889172
# 96  real -279.41263   64.633440  20.823914  32.152424 -17.787588 -22.698908
# 97  real -314.13046   58.319435  15.274138  41.815270 -16.077265 -12.502652
# 98  real -304.28607  118.908540  -5.906505  -4.827681 -14.297681 -20.907170
# 99  real -278.84670   53.916985  19.560787  23.711021 -24.027920 -16.273907
#
# ...

# %%
fake
# Out:
#     label          0           1          2          3          4          5  \
# 100  fake -270.16810   70.037540   4.593485   9.827960 -18.602259 -26.047564
# 101  fake -286.23438  118.378624 -10.373878  12.667923 -16.827732 -31.922716
# 102  fake -261.75385   70.738780   4.403077   5.113412 -18.326668 -24.143469
# 103  fake -291.36930   67.078670   2.300191   9.510673 -18.434425 -20.529629
# 104  fake -285.62418   76.943870   8.580459  20.126108 -12.824420 -32.405050
# ..    ...        ...         ...        ...        ...        ...        ...
# 192  fake -296.73276   98.087870  -6.969804   9.237810 -14.932974 -26.105984
# 193  fake -297.21432   72.656850  14.818332  14.452042 -16.384123 -19.401957
# 194  fake -275.80368   80.892390   8.894267   7.113605 -22.349508 -25.666887
# 195  fake -295.57413   86.443110 -12.279798   8.740219 -14.250678 -21.122461
# 196  fake -292.48965   72.542625   4.686722  11.017757 -17.455631 -13.377519
#
# ...

# %%
real = real.sample(frac=1, random_state=24).reset_index(drop=True)
fake = fake.sample(frac=1,random_state=24).reset_index(drop=True)

# %%
real
# Out:
#    label          0           1          2          3          4          5  \
# 0   real -398.57117   95.891060   9.011795   8.306079 -25.278109  -1.686588
# 1   real -322.88754  113.605790   3.250193   4.232692 -44.848316 -15.535991
# 2   real -276.38770  118.662090 -40.245125  -4.663483 -24.894941 -30.471863
# 3   real -367.67890   53.707977  25.484419  11.136240 -18.807196 -10.244793
# 4   real -294.50520   74.410515  33.712227  22.271439 -44.646523 -34.148540
# ..   ...        ...         ...        ...        ...        ...        ...
# 95  real -298.68910   59.886307  -3.170834  -2.236311 -19.924460 -12.746608
# 96  real -299.07538   68.015564  12.800464  26.978304 -17.917780 -18.536451
# 97  real -317.96200   65.692960   0.821691  17.735956 -11.206700 -22.846502
# 98  real -260.43338  101.535420 -41.664314  -6.018332 -26.039772 -23.073729
# 99  real -309.81560   89.154010   5.823233  47.214706 -11.467693 -37.416560
#
# ...

# %%
real_test_val = real.iloc[:int(len(real)*.2),:]
real_trian  = real.iloc[int(len(real)*.2):,:]

# %%
real_test_val
# Out:
#    label          0           1          2          3          4          5  \
# 0   real -398.57117   95.891060   9.011795   8.306079 -25.278109  -1.686588
# 1   real -322.88754  113.605790   3.250193   4.232692 -44.848316 -15.535991
# 2   real -276.38770  118.662090 -40.245125  -4.663483 -24.894941 -30.471863
# 3   real -367.67890   53.707977  25.484419  11.136240 -18.807196 -10.244793
# 4   real -294.50520   74.410515  33.712227  22.271439 -44.646523 -34.148540
# 5   real -367.42730  133.961940 -15.064163   7.470857 -13.872409 -26.781492
# 6   real -320.60785  102.470055  -0.133408  19.804306 -11.651501 -25.882850
# 7   real -298.01135   69.589690  17.450228  26.797546 -12.706161 -22.771248
# 8   real -294.99692   64.677216   1.613736   9.460479 -41.527256 -11.119249
# 9   real -301.43173   91.281530  -3.918897  25.117758  -3.376515 -24.344025
# 10  real -328.38278   73.102030  13.828528   9.522263 -15.608756  -1.024640
# ...

# %%
real_trian
# Out:
#    label          0           1          2          3          4          5  \
# 20  real -346.22195   62.606815  15.470532  50.548313  -4.125321 -30.642038
# 21  real -316.10327  120.189070   6.176297   1.521950 -26.202164 -10.610514
# 22  real -286.61353   34.660410  27.828785  38.408930 -14.240249 -27.532421
# 23  real -351.45786   57.367104  25.991817  47.678326  -3.299080 -30.197136
# 24  real -317.83320  113.219185 -10.552312  -3.246732 -22.017174 -21.526033
# ..   ...        ...         ...        ...        ...        ...        ...
# 95  real -298.68910   59.886307  -3.170834  -2.236311 -19.924460 -12.746608
# 96  real -299.07538   68.015564  12.800464  26.978304 -17.917780 -18.536451
# 97  real -317.96200   65.692960   0.821691  17.735956 -11.206700 -22.846502
# 98  real -260.43338  101.535420 -41.664314  -6.018332 -26.039772 -23.073729
# 99  real -309.81560   89.154010   5.823233  47.214706 -11.467693 -37.416560
#
# ...

# %%
real_test = real_test_val.iloc[:int(len(real_test_val)//2),:]
real_val = real_test_val.iloc[int(len(real_test_val)//2):,:]

# %%
real_test
# Out:
#   label          0           1          2          3          4          5  \
# 0  real -398.57117   95.891060   9.011795   8.306079 -25.278109  -1.686588
# 1  real -322.88754  113.605790   3.250193   4.232692 -44.848316 -15.535991
# 2  real -276.38770  118.662090 -40.245125  -4.663483 -24.894941 -30.471863
# 3  real -367.67890   53.707977  25.484419  11.136240 -18.807196 -10.244793
# 4  real -294.50520   74.410515  33.712227  22.271439 -44.646523 -34.148540
# 5  real -367.42730  133.961940 -15.064163   7.470857 -13.872409 -26.781492
# 6  real -320.60785  102.470055  -0.133408  19.804306 -11.651501 -25.882850
# 7  real -298.01135   69.589690  17.450228  26.797546 -12.706161 -22.771248
# 8  real -294.99692   64.677216   1.613736   9.460479 -41.527256 -11.119249
# 9  real -301.43173   91.281530  -3.918897  25.117758  -3.376515 -24.344025
#
#            6          7          8  ...       118       119       120  \
# 0 -20.659914 -24.201117  -8.581908  ... -0.199294 -0.047478 -0.463359
# ...

# %%
real_val
# Out:
#    label          0           1          2          3          4          5  \
# 10  real -328.38278   73.102030  13.828528   9.522263 -15.608756  -1.024640
# 11  real -293.28020   80.571420   9.796677  12.757751 -11.359370 -12.083328
# 12  real -271.09740  115.993720  -6.429112   8.188643 -38.819860 -24.170055
# 13  real -282.55878   90.871370  -8.748867   9.705892 -22.400118 -19.308727
# 14  real -294.49435   82.242096  11.394211  23.832580  -8.023302 -19.681633
# 15  real -288.43103   61.815662   9.400849  35.808853 -15.602504 -22.166153
# 16  real -283.48800   29.727652  29.739656  22.043123 -21.379587 -32.592606
# 17  real -382.79250  100.769210  11.367582   8.263332 -19.349579 -23.631851
# 18  real -315.78967   61.585377   7.298950  22.221277 -11.358147 -15.252738
# 19  real -346.33743   91.017730  20.352385  22.764545 -21.270315 -32.463932
#
#             6          7          8  ...       118       119       120  \
# ...

# %%
fake
# Out:
#    label          0          1          2          3          4          5  \
# 0   fake -301.78770  68.743385   6.748144   8.772201 -20.069200 -17.294573
# 1   fake -287.54352  71.696556   2.909544   6.614386 -17.984905 -25.903929
# 2   fake -306.16968  65.308800   4.308022   6.136176 -11.110737 -23.818226
# 3   fake -284.66428  84.222420  -3.635457  -1.194207 -26.431630 -20.597242
# 4   fake -281.39877  78.541176  -0.844248   7.536555 -18.390928 -25.562387
# ..   ...        ...        ...        ...        ...        ...        ...
# 92  fake -277.02686  90.790535  -6.800740   4.913638 -20.579117 -25.414816
# 93  fake -280.55910  71.443940   3.022366  10.964078 -19.975307 -21.201290
# 94  fake -286.79520  88.419876 -10.428265  10.303459 -14.974736 -24.426330
# 95  fake -291.36930  67.078670   2.300191   9.510673 -18.434425 -20.529629
# 96  fake -302.29930  86.920100   5.600632   7.756184 -15.436276 -21.847853
#
# ...

# %%
fake_test_val = fake.iloc[:int(len(fake)*.2),:]
fake_trian  = fake.iloc[int(len(fake)*.2):,:]

# %%
fake_trian
# Out:
#    label          0          1          2          3          4          5  \
# 19  fake -285.22888  76.679375   3.150990  27.460844 -11.605445 -33.944410
# 20  fake -278.93216  62.534530  -0.066193  26.055807 -11.202950 -35.285805
# 21  fake -282.63788  60.257595   0.330151  11.334283 -17.088255 -21.310122
# 22  fake -278.17450  80.550830  -4.742765   9.507203 -13.085870 -26.654910
# 23  fake -301.96362  53.682990  10.107789  27.647772 -11.489565 -29.372047
# ..   ...        ...        ...        ...        ...        ...        ...
# 92  fake -277.02686  90.790535  -6.800740   4.913638 -20.579117 -25.414816
# 93  fake -280.55910  71.443940   3.022366  10.964078 -19.975307 -21.201290
# 94  fake -286.79520  88.419876 -10.428265  10.303459 -14.974736 -24.426330
# 95  fake -291.36930  67.078670   2.300191   9.510673 -18.434425 -20.529629
# 96  fake -302.29930  86.920100   5.600632   7.756184 -15.436276 -21.847853
#
# ...

# %%
fake_test = fake_test_val.iloc[:len(fake_test_val)//2,:]
fake_val = fake_test_val.iloc[len(fake_test_val)//2:,:]

# %%
fake_test
# Out:
#   label          0          1         2          3          4          5  \
# 0  fake -301.78770  68.743385  6.748144   8.772201 -20.069200 -17.294573
# 1  fake -287.54352  71.696556  2.909544   6.614386 -17.984905 -25.903929
# 2  fake -306.16968  65.308800  4.308022   6.136176 -11.110737 -23.818226
# 3  fake -284.66428  84.222420 -3.635457  -1.194207 -26.431630 -20.597242
# 4  fake -281.39877  78.541176 -0.844248   7.536555 -18.390928 -25.562387
# 5  fake -291.57730  65.909110  4.955727  16.622314 -13.672531 -25.460497
# 6  fake -276.05225  89.607240 -6.013930  -3.519041 -18.582987 -20.543730
# 7  fake -296.63834  93.897530 -5.995059   5.793170 -17.446630 -23.526678
# 8  fake -305.95822  76.587060  3.232241  23.628021 -15.945227 -28.954466
#
#            6          7          8  ...       118       119       120  \
# 0 -24.823671 -14.525412 -14.395689  ...  0.214812 -0.247547  0.017350
# 1 -29.353453 -11.476893 -14.093259  ...  0.200234  0.015411  0.121348
# ...

# %%
all_test= pd.concat([fake_test,real_test], axis=0)

# %%
all_test
# Out:
#   label          0           1          2          3          4          5  \
# 0  fake -301.78770   68.743385   6.748144   8.772201 -20.069200 -17.294573
# 1  fake -287.54352   71.696556   2.909544   6.614386 -17.984905 -25.903929
# 2  fake -306.16968   65.308800   4.308022   6.136176 -11.110737 -23.818226
# 3  fake -284.66428   84.222420  -3.635457  -1.194207 -26.431630 -20.597242
# 4  fake -281.39877   78.541176  -0.844248   7.536555 -18.390928 -25.562387
# 5  fake -291.57730   65.909110   4.955727  16.622314 -13.672531 -25.460497
# 6  fake -276.05225   89.607240  -6.013930  -3.519041 -18.582987 -20.543730
# 7  fake -296.63834   93.897530  -5.995059   5.793170 -17.446630 -23.526678
# 8  fake -305.95822   76.587060   3.232241  23.628021 -15.945227 -28.954466
# 0  real -398.57117   95.891060   9.011795   8.306079 -25.278109  -1.686588
# 1  real -322.88754  113.605790   3.250193   4.232692 -44.848316 -15.535991
# ...

# %%
all_val= pd.concat([fake_val,real_val], axis=0)

# %%
all_val
# Out:
#    label          0           1          2          3          4          5  \
# 9   fake -284.75890   86.955310  -5.343262   5.102979 -17.948370 -27.881601
# 10  fake -282.11963   87.730865  -5.210908   4.884820 -18.254799 -25.567389
# 11  fake -292.46630   90.318670  -5.249431  21.135487 -13.767186 -26.998049
# 12  fake -296.80637   78.616960   4.043401  14.429915 -15.425669 -25.969019
# 13  fake -294.68753   83.171165   3.781627   6.270817 -21.791851 -23.276760
# 14  fake -272.28190   72.964300   0.721001  -2.804487 -23.209272 -21.642010
# 15  fake -284.10403   66.351360   5.914715  14.625688 -18.045400 -25.256994
# 16  fake -274.44890   72.942696  -2.138609   7.307342 -22.962126 -24.576212
# 17  fake -294.56960   34.679310   8.659508  18.510897 -11.348831 -21.174389
# 18  fake -288.34670   66.992510  -0.456530  14.165454 -13.471884 -25.254047
# 10  real -328.38278   73.102030  13.828528   9.522263 -15.608756  -1.024640
# ...

# %%
all_val.to_csv(".//spliting data//all_val.csv",index=False)
all_test.to_csv(".//spliting data//all_test.csv",index=False)

# %%
fake_trian
# Out:
#    label          0          1          2          3          4          5  \
# 19  fake -285.22888  76.679375   3.150990  27.460844 -11.605445 -33.944410
# 20  fake -278.93216  62.534530  -0.066193  26.055807 -11.202950 -35.285805
# 21  fake -282.63788  60.257595   0.330151  11.334283 -17.088255 -21.310122
# 22  fake -278.17450  80.550830  -4.742765   9.507203 -13.085870 -26.654910
# 23  fake -301.96362  53.682990  10.107789  27.647772 -11.489565 -29.372047
# ..   ...        ...        ...        ...        ...        ...        ...
# 92  fake -277.02686  90.790535  -6.800740   4.913638 -20.579117 -25.414816
# 93  fake -280.55910  71.443940   3.022366  10.964078 -19.975307 -21.201290
# 94  fake -286.79520  88.419876 -10.428265  10.303459 -14.974736 -24.426330
# 95  fake -291.36930  67.078670   2.300191   9.510673 -18.434425 -20.529629
# 96  fake -302.29930  86.920100   5.600632   7.756184 -15.436276 -21.847853
#
# ...

# %%
count=len(fake_trian)
part_1_fake_trian=fake_trian.iloc[:count//5,:]
part_2_fake_trian=fake_trian.iloc[count//5:(count//5)*2,:]
part_3_fake_trian=fake_trian.iloc[(count//5)*2:(count//5)*3,:]
part_4_fake_trian=fake_trian.iloc[(count//5)*3:(count//5)*4,:]
part_5_fake_trian=fake_trian.iloc[(count//5)*4:,:]

# %%
part_1_fake_trian
# Out:
#    label          0           1          2          3          4          5  \
# 19  fake -285.22888   76.679375   3.150990  27.460844 -11.605445 -33.944410
# 20  fake -278.93216   62.534530  -0.066193  26.055807 -11.202950 -35.285805
# 21  fake -282.63788   60.257595   0.330151  11.334283 -17.088255 -21.310122
# 22  fake -278.17450   80.550830  -4.742765   9.507203 -13.085870 -26.654910
# 23  fake -301.96362   53.682990  10.107789  27.647772 -11.489565 -29.372047
# 24  fake -303.57556   93.136090   5.701390  10.341168 -20.483791 -22.735134
# 25  fake -313.08994   87.009680  -1.157979  13.939153 -14.590451 -24.829575
# 26  fake -273.23746   81.243000   6.610447  -0.692086 -21.375107 -24.616327
# 27  fake -294.24045   58.533634  10.603563  19.133226 -21.823198 -23.929327
# 28  fake -276.88193   71.260260  -1.365798   1.585157 -19.145315 -26.047405
# 29  fake -272.05120   74.371350  -2.899904  15.214906 -21.221880 -33.541824
# ...

# %%
part_5_fake_trian
# Out:
#    label          0           1          2          3          4          5  \
# 79  fake -286.79605   90.711494   1.703043  10.185963 -31.600437 -27.815850
# 80  fake -305.40030   78.131020  -1.120546   9.382060 -19.829967 -20.417192
# 81  fake -305.94547   86.513440  -2.753574   2.871129 -25.323505 -30.621216
# 82  fake -279.48360   66.280815  -1.031367   7.062682 -13.769270 -22.734554
# 83  fake -270.43555   71.295080   0.982284   7.432947 -22.499758 -28.134222
# 84  fake -292.68076   83.712720   2.171086  17.715918 -16.035666 -26.142626
# 85  fake -274.49475   82.414970  -5.814219  10.417028 -18.770998 -29.752768
# 86  fake -281.22107   82.227410  -6.138618   6.705706 -21.315102 -27.436699
# 87  fake -288.53018   89.097890   6.173037   4.125561 -21.679285 -31.665730
# 88  fake -285.62418   76.943870   8.580459  20.126108 -12.824420 -32.405050
# 89  fake -272.07950   70.257290   1.760682   8.630212 -16.187496 -27.453537
# ...

# %%
real_trian
# Out:
#    label          0           1          2          3          4          5  \
# 20  real -346.22195   62.606815  15.470532  50.548313  -4.125321 -30.642038
# 21  real -316.10327  120.189070   6.176297   1.521950 -26.202164 -10.610514
# 22  real -286.61353   34.660410  27.828785  38.408930 -14.240249 -27.532421
# 23  real -351.45786   57.367104  25.991817  47.678326  -3.299080 -30.197136
# 24  real -317.83320  113.219185 -10.552312  -3.246732 -22.017174 -21.526033
# ..   ...        ...         ...        ...        ...        ...        ...
# 95  real -298.68910   59.886307  -3.170834  -2.236311 -19.924460 -12.746608
# 96  real -299.07538   68.015564  12.800464  26.978304 -17.917780 -18.536451
# 97  real -317.96200   65.692960   0.821691  17.735956 -11.206700 -22.846502
# 98  real -260.43338  101.535420 -41.664314  -6.018332 -26.039772 -23.073729
# 99  real -309.81560   89.154010   5.823233  47.214706 -11.467693 -37.416560
#
# ...

# %%
count=len(real_trian)
part_1_real_trian=real_trian.iloc[:count //5,:]
part_2_real_trian=real_trian.iloc[count //5:(count //5)*2,:]
part_3_real_trian=real_trian.iloc[(count //5)*2:(count //5)*3,:]
part_4_real_trian=real_trian.iloc[(count //5)*3:(count //5)*4,:]
part_5_real_trian=real_trian.iloc[(count //5)*4:,:]

# %%
part_1_real_trian
# Out:
#    label          0           1          2          3          4          5  \
# 20  real -346.22195   62.606815  15.470532  50.548313  -4.125321 -30.642038
# 21  real -316.10327  120.189070   6.176297   1.521950 -26.202164 -10.610514
# 22  real -286.61353   34.660410  27.828785  38.408930 -14.240249 -27.532421
# 23  real -351.45786   57.367104  25.991817  47.678326  -3.299080 -30.197136
# 24  real -317.83320  113.219185 -10.552312  -3.246732 -22.017174 -21.526033
# 25  real -302.57303   78.049780   0.295905  36.314278  -8.678719 -34.353348
# 26  real -324.88562  119.507160  14.748030 -16.231358 -58.236332 -21.782490
# 27  real -293.34262  116.586510   4.921299  -4.266944 -36.278170 -28.913298
# 28  real -294.70602  121.242100 -23.837107  18.710205 -15.066543 -19.661762
# 29  real -312.89066   97.530090   5.803292 -19.719742 -16.609182  -4.287791
# 30  real -313.82780  101.104300  -3.810565  28.001696  -1.126818 -29.126791
# ...

# %%
train_part_1= pd.concat([part_1_real_trian,part_1_fake_trian], axis=0)
train_part_2= pd.concat([part_2_real_trian,part_2_fake_trian], axis=0)
train_part_3= pd.concat([part_3_real_trian,part_3_fake_trian], axis=0)
train_part_4= pd.concat([part_4_real_trian,part_4_fake_trian], axis=0)
train_part_5= pd.concat([part_5_real_trian,part_5_fake_trian], axis=0)

# %%
train_part_1.to_csv(".//spliting data//train part_1.csv",index=False)
train_part_2.to_csv(".//spliting data//train part_2.csv",index=False)
train_part_3.to_csv(".//spliting data//train part_3.csv",index=False)
train_part_4.to_csv(".//spliting data//train part_4.csv",index=False)
train_part_5.to_csv(".//spliting data//train part_5.csv",index=False)
